# %%
import util.data_loading
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = util.data_loading.load_raw_data('PropertyTax_DataSet_Cleaned.csv')
# Out:
# Looking for file at: C:\Users\krikr\CA_Housing_Analysis\data\PropertyTax_DataSet_Cleaned.csv

# %%
df
# Out:
#     Entity Name  Entity ID  Fiscal Year  \
# 0       Alameda        117         2019
# 1        Alpine        118         2019
# 2        Amador        119         2019
# 3         Butte        120         2019
# 4     Calaveras        121         2019
# ..          ...        ...          ...
# 981      Tulare        170         2003
# 982    Tuolumne        171         2003
# 983     Ventura        172         2003
# 984        Yolo        173         2003
# 985        Yuba        174         2003
#
#      Secured_Net Taxable Value_Countywide Property Taxes  \
# 0                                         277914233900
# 1                                            710871500
# 2                                           5242246166
# 3                                          22124812484
# 4                                           7189420543
# ..                                                 ...
# 981                                        15958244493
# 982                                         3921643697
# 983                                        62615312920
# 984                                        11328158951
# 985                                         2444134281
#
#      Unsecured_Net Taxable Value_Countywide Property Taxes  \
# 0                                          13669817723
# 1                                             42200190
# 2                                             74907168
# 3                                           1159408507
# 4                                            108152546
# ..                                                 ...
# 981                                          793190268
# 982                                          135667744
# 983                                         3316205938
# 984                                          877627734
# 985                                          166932959
#
#      Secured_Tax Rate 1%_Countywide Property Taxes  \
# 0                                       2779142339
# 1                                          7108715
# 2                                         52422462
# 3                                        221248125
# 4                                         71894205
# ..                                             ...
# 981                                      159582445
# 982                                       39216437
# 983                                      626153129
# 984                                      113281590
# 985                                       24441343
#
#      Unsecured_Tax Rate 1%_Countywide Property Taxes  \
# 0                                          136698177
# 1                                             422002
# 2                                             749072
# 3                                           11594085
# 4                                            1081525
# ..                                               ...
# 981                                          7931903
# 982                                          1356677
# 983                                         33162059
# 984                                          8776277
# 985                                          1669330
#
#      Tax Rate 1%: Homeowners Property Tax Reimbursement (HOPTR)  \
# 0                                             17273350
# 1                                                15624
# 2                                               596754
# 3                                              2675053
# 4                                               744665
# ..                                                 ...
# 981                                            3540371
# 982                                             905862
# 983                                            9477335
# 984                                            1957848
# 985                                             671659
#
#      Total_Countywide Property Taxes
# 0                         2933113866
# 1                            7546341
# 2                           53768288
# 3                          235517263
# 4                           71983302
# ..                               ...
# 981                        171054719
# 982                         41478976
# 983                        668792523
# 984                        124014210
# 985                         26782332
#
# [986 rows x 9 columns]

# %%
df.shape
# Out:
# (986, 9)

# %%
df["Entity Name"]
# Out:
# 0        Alameda
# 1         Alpine
# 2         Amador
# 3          Butte
# 4      Calaveras
#          ...
# 981       Tulare
# 982     Tuolumne
# 983      Ventura
# 984         Yolo
# 985         Yuba
# Name: Entity Name, Length: 986, dtype: object

# %%
df["Fiscal Year"] = df["Fiscal Year"].astype(int)

# %%
df["Fiscal Year"].max()
# Out:
# np.int64(2019)

# %%
san_diego_df = df[df["Entity Name"] ==  "San Diego"]

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_df, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
san_diego_df = df[df["Entity Name"] ==  "San Diego"]
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 3
#       1 san_diego_df = df[df["Entity Name"] ==  "San Diego"]
#       2 plt.figure(figsize=(14,6))
# ----> 3 sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
#       4 ax = plt.gca()
#       6 plt.xticks(rotation=45)
#
# NameError: name 'san_diego_tax' is not defined

# %%
san_diego_df = df[df["Entity Name"] ==  "Los Angeles"]
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
san_diego_df = df[df["Entity Name"] ==  "Orange"]
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
