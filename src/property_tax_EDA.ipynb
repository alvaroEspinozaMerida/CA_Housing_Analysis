# %%
import util.data_loading
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = util.data_loading.load_raw_data('PropertyTax_DataSet_Cleaned.csv')
# Out:
# Looking for file at: /Users/aaaaalaverga/DataspellProjects/CA_Housing_Analysis/data/PropertyTax_DataSet_Cleaned.csv

# %%
df
# Out:
#     Entity Name  Entity ID  Fiscal Year  \
# 0       Alameda        117         2019
# 1        Alpine        118         2019
# 2        Amador        119         2019
# 3         Butte        120         2019
# 4     Calaveras        121         2019
# ..          ...        ...          ...
# 981      Tulare        170         2003
# 982    Tuolumne        171         2003
# 983     Ventura        172         2003
# 984        Yolo        173         2003
# 985        Yuba        174         2003
#
#      Secured_Net Taxable Value_Countywide Property Taxes  \
# 0                                         277914233900
# 1                                            710871500
# 2                                           5242246166
# 3                                          22124812484
# 4                                           7189420543
# ..                                                 ...
# 981                                        15958244493
# ...

# %%
df.shape
# Out:
# (986, 9)

# %%
df["Entity Name"]
# Out:
# 0        Alameda
# 1         Alpine
# 2         Amador
# 3          Butte
# 4      Calaveras
#          ...
# 981       Tulare
# 982     Tuolumne
# 983      Ventura
# 984         Yolo
# 985         Yuba
# Name: Entity Name, Length: 986, dtype: object

# %%
df["Fiscal Year"] = df["Fiscal Year"].astype(int)

# %%
df["Fiscal Year"].max()
# Out:
# np.int64(2019)

# %%
san_diego_df = df[df["Entity Name"] ==  "San Diego"]

# %%
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_df, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
san_diego_df = df[df["Entity Name"] ==  "San Diego"]
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
san_diego_df = df[df["Entity Name"] ==  "Los Angeles"]
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %%
san_diego_df = df[df["Entity Name"] ==  "Orange"]
plt.figure(figsize=(14,6))
sns.scatterplot(data = san_diego_tax, x = "Fiscal Year", y ="Secured_Net Taxable Value_Countywide Property Taxes")
ax = plt.gca()

plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
